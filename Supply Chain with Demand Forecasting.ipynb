# %% [markdown]
# # **Supply Chain Optimization with Demand Forecasting**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
features = pd.read_csv('/content/drive/MyDrive/features.csv')

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
train = pd.read_csv('/content/drive/MyDrive/train (1).csv')
train.head(2)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True

# %%
test = pd.read_csv('/content/drive/MyDrive/test (1).csv')
test.head(2)
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False

# %%
stores = pd.read_csv('/content/drive/MyDrive/stores.csv')
stores.head(2)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307

# %%
train.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %%
stores.columns
# Out:
# Index(['Store', 'Type', 'Size'], dtype='object')

# %%
data = train.merge(stores, how ='left', on = 'Store')

# %%
features.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %%
data = data.merge(features, how = 'left', on = ['Store', 'Date'])

# %%
data.head(2)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 0      1     1  2010-02-05      24924.50        False    A  151315
# 1      1     1  2010-02-12      46039.49         True    A  151315
#
#    Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0        42.31       2.572        NaN        NaN        NaN        NaN
# 1        38.51       2.548        NaN        NaN        NaN        NaN
#
#    MarkDown5         CPI  Unemployment  IsHoliday_y
# 0        NaN  211.096358         8.106        False
# 1        NaN  211.242170         8.106         True

# %%
data.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday_x', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday_y'],
#       dtype='object')

# %%
len(data['Store'])
# Out:
# 421570

# %%
train['Store'].nunique()
# Out:
# 45

# %%
len(train['Store'])
# Out:
# 421570

# %%
stores['Store'].nunique()
# Out:
# 45

# %%
len(stores['Store'])
# Out:
# 45

# %%
len(data['Store'])
# Out:
# 421570

# %%
features['Store'].nunique()
# Out:
# 45

# %%
len(features['Store'])
# Out:
# 8190

# %%
features.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday_x   421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
#  16  IsHoliday_y   421570 non-null  bool
# dtypes: bool(2), float64(10), int64(3), object(2)
# memory usage: 49.0+ MB

# %% [markdown]
# # Check Null

# %%
data.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday_x          0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday_y          0
# dtype: int64

# %%
data.head(3)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 0      1     1  2010-02-05      24924.50        False    A  151315
# 1      1     1  2010-02-12      46039.49         True    A  151315
# 2      1     1  2010-02-19      41595.55        False    A  151315
#
#    Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0        42.31       2.572        NaN        NaN        NaN        NaN
# 1        38.51       2.548        NaN        NaN        NaN        NaN
# 2        39.93       2.514        NaN        NaN        NaN        NaN
#
#    MarkDown5         CPI  Unemployment  IsHoliday_y
# 0        NaN  211.096358         8.106        False
# 1        NaN  211.242170         8.106         True
# 2        NaN  211.289143         8.106        False

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data = data.sort_values(by='Date')

# %%
data.head()
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 0           1     1 2010-02-05      24924.50        False    A  151315
# 277665     29     5 2010-02-05      15552.08        False    B   93638
# 277808     29     6 2010-02-05       3200.22        False    B   93638
# 277951     29     7 2010-02-05      10820.05        False    B   93638
# 278094     29     8 2010-02-05      20055.64        False    B   93638
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 277665        24.36       2.788        NaN        NaN        NaN        NaN
# 277808        24.36       2.788        NaN        NaN        NaN        NaN
# 277951        24.36       2.788        NaN        NaN        NaN        NaN
# 278094        24.36       2.788        NaN        NaN        NaN        NaN
#
#         MarkDown5         CPI  Unemployment  IsHoliday_y
# 0             NaN  211.096358         8.106        False
# 277665        NaN  131.527903        10.064        False
# 277808        NaN  131.527903        10.064        False
# 277951        NaN  131.527903        10.064        False
# 278094        NaN  131.527903        10.064        False

# %%
data.tail()
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 379648     40    87 2012-10-26      24638.96        False    A  155083
# 181170     19    30 2012-10-26       3740.12        False    A  203819
# 181313     19    31 2012-10-26       3128.17        False    A  203819
# 181599     19    33 2012-10-26       5740.14        False    A  203819
# 421569     45    98 2012-10-26       1076.80        False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 379648        49.65       3.917    3605.71      55.98       0.28     486.81
# 181170        56.49       4.071    5430.75      90.07        NaN     904.34
# 181313        56.49       4.071    5430.75      90.07        NaN     904.34
# 181599        56.49       4.071    5430.75      90.07        NaN     904.34
# 421569        58.85       3.882    4018.91      58.08     100.00     211.94
#
#         MarkDown5         CPI  Unemployment  IsHoliday_y
# 379648    1389.06  138.728161         4.145        False
# 181170    1665.77  138.728161         7.992        False
# 181313    1665.77  138.728161         7.992        False
# 181599    1665.77  138.728161         7.992        False
# 421569     858.33  192.308899         8.667        False

# %%
data.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday_x          0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday_y          0
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# Store            0.000000
# Dept             0.000000
# Date             0.000000
# Weekly_Sales     0.000000
# IsHoliday_x      0.000000
# Type             0.000000
# Size             0.000000
# Temperature      0.000000
# Fuel_Price       0.000000
# MarkDown1       64.257181
# MarkDown2       73.611025
# MarkDown3       67.480845
# MarkDown4       67.984676
# MarkDown5       64.079038
# CPI              0.000000
# Unemployment     0.000000
# IsHoliday_y      0.000000
# dtype: float64

# %%
numerical_columns = data.select_dtypes(include=[np.number]).columns
numerical_columns
# Out:
# Index(['Store', 'Dept', 'Weekly_Sales', 'Size', 'Temperature', 'Fuel_Price',
#        'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI',
#        'Unemployment'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 421570 entries, 0 to 421569
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday_x   421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
#  16  IsHoliday_y   421570 non-null  bool
# dtypes: bool(2), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 52.3+ MB

# %% [markdown]
# # fill na with median

# %%
data[numerical_columns] = data[numerical_columns].fillna(data[numerical_columns].median())         # ? median

# %%
data['MarkDown1'].max()
# Out:
# 88646.76

# %%
data['MarkDown1'].min()
# Out:
# 0.27

# %%
data['MarkDown1'].median()
# Out:
# 5347.45

# %%
data['MarkDown1'].mode()
# Out:
# 0    5347.45
# Name: MarkDown1, dtype: float64

# %%
data.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday_x     0
# Type            0
# Size            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday_y     0
# dtype: int64

# %%
data.mode()
# Out:
#     Store  Dept       Date  Weekly_Sales IsHoliday_x Type     Size  \
# 0    13.0     1 2011-12-23          10.0       False    A  39690.0
# 1     NaN     2        NaT           NaN         NaN  NaN      NaN
# 2     NaN     3        NaT           NaN         NaN  NaN      NaN
# 3     NaN     4        NaT           NaN         NaN  NaN      NaN
# 4     NaN     7        NaT           NaN         NaN  NaN      NaN
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572    5347.45      192.0       24.6    1481.31
# 277665        24.36       2.788    5347.45      192.0       24.6    1481.31
# 277808        24.36       2.788    5347.45      192.0       24.6    1481.31
# 277951        24.36       2.788    5347.45      192.0       24.6    1481.31
# 278094        24.36       2.788    5347.45      192.0       24.6    1481.31
#
#         MarkDown5         CPI  Unemployment  IsHoliday_y
# 0         3359.45  211.096358         8.106        False
# 277665    3359.45  131.527903        10.064        False
# 277808    3359.45  131.527903        10.064        False
# 277951    3359.45  131.527903        10.064        False
# 278094    3359.45  131.527903        10.064        False

# %%
data = data.fillna(data.mode().iloc[0])           # ?

# %%
data['year'] = data['Date'].dt.year

# %%
data['month'] = data['Date'].dt.month

data['Day'] = data['Date'].dt.day

# %%
data['Week'] = data['Date'].dt.isocalendar().week             # ??

# %%
data['Dayodweek'] = data['Date'].dt.dayofweek                # ??

# %%
data.head(3)
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 0           1     1 2010-02-05      24924.50        False    A  151315
# 277665     29     5 2010-02-05      15552.08        False    B   93638
# 277808     29     6 2010-02-05       3200.22        False    B   93638
#
#         Temperature  Fuel_Price  MarkDown1  ...  MarkDown4  MarkDown5  \
# 0             42.31       2.572    5347.45  ...    1481.31    3359.45
# 277665        24.36       2.788    5347.45  ...    1481.31    3359.45
# 277808        24.36       2.788    5347.45  ...    1481.31    3359.45
#
#                CPI  Unemployment  IsHoliday_y  year  month  Day  Week  \
# 0       211.096358         8.106        False  2010      2    5     5
# 277665  131.527903        10.064        False  2010      2    5     5
# 277808  131.527903        10.064        False  2010      2    5     5
#
#         Dayodweek
# 0               4
# 277665          4
# 277808          4
#
# [3 rows x 22 columns]

# %%
categorical_columns = data.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['Type'], dtype='object')

# %%
if len(categorical_columns) > 0:
   data = pd.get_dummies(data, columns = categorical_columns, drop_first = True)

# %%
data.head()
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday_x    Size  \
# 0           1     1 2010-02-05      24924.50        False  151315
# 277665     29     5 2010-02-05      15552.08        False   93638
# 277808     29     6 2010-02-05       3200.22        False   93638
# 277951     29     7 2010-02-05      10820.05        False   93638
# 278094     29     8 2010-02-05      20055.64        False   93638
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  ...         CPI  \
# 0             42.31       2.572    5347.45      192.0  ...  211.096358
# 277665        24.36       2.788    5347.45      192.0  ...  131.527903
# 277808        24.36       2.788    5347.45      192.0  ...  131.527903
# 277951        24.36       2.788    5347.45      192.0  ...  131.527903
# 278094        24.36       2.788    5347.45      192.0  ...  131.527903
#
#         Unemployment  IsHoliday_y  year  month  Day  Week  Dayodweek  Type_B  \
# 0              8.106        False  2010      2    5     5          4   False
# 277665        10.064        False  2010      2    5     5          4    True
# 277808        10.064        False  2010      2    5     5          4    True
# 277951        10.064        False  2010      2    5     5          4    True
# 278094        10.064        False  2010      2    5     5          4    True
#
#         Type_C
# 0        False
# 277665   False
# 277808   False
# 277951   False
# 278094   False
#
# [5 rows x 23 columns]

# %% [markdown]
# # Model Buliding

# %%
x = data.drop(columns=['Date', 'Weekly_Sales'])
y = data['Weekly_Sales']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([26452.31712745, 14177.52211351, 22339.33265658, ...,
#        21106.09686486, 14876.31863845,  2754.67850462])

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 471988613.85739404

# %%
r2 = r2_score(y_test, y_pred)

# %% [markdown]
# # **2nd Model**

# %%
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error : {mse}")
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error : 11956040.414050885
# R-Squared: 0.9770076482093315
